# %%
9
# Out:
# 9

# %%
10+5
# Out:
# 15

# %%
10/5 #float division
# Out:
# 2.0

# %%
import sys
sys.version
# Out:
# '3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len (keyword.kwlist)
# Out:
# 35

# %%
#variable

# %%
a=5
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
id(a)
# Out:
# 10750984

# %%
b=5.5
b
# Out:
# 5.5

# %%
type(b)
# Out:
# float

# %%
age=25          #int variable
print(age)
# Out:
# 25

# %%
name ="Deadpool" #string variable
print (name)
# Out:
# Deadpool

# %%
a=5
type(a)
# Out:
# int

# %%
price =10.59   #float variable
print(price)
# Out:
# 10.59

# %%
is_active=True  #booleean variable
is_active
# Out:
# True

# %%
x=10     #storing and printing
print (x)
# Out:
# 10

# %%
a=3             #using variables in expressions
b=5
result=a+b
print (result)
# Out:
# 8

# %%
score = 30
print (score)
# Out:
# 30

# %%
score = 50  #changing value of variable
print(score)
# Out:
# 50

# %%
first_name = 'kiran'           #concatenate strings
last_name = 'sankineni'
full_name = first_name+' '+last_name
print (full_name)
# Out:
# kiran sankineni

# %%
length = 30              #using variables in calculations
width = 20
area= length*width
print(area)
# Out:
# 600
